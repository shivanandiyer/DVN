# %% [markdown]
# <img src="https://prismic-io.s3.amazonaws.com/plotly-marketing-website/bd1f702a-b623-48ab-a459-3ee92a7499b4_logo-plotly.svg">
#
# ## Interactive Maps with Plotly

# %%
import plotly.express as px

df = px.data.gapminder().query("year == 2007")

# %% [markdown]
# ### Simple Scatter Plot on a Map

# %%
fig = px.scatter_geo(df,
                     locations="iso_alpha",
                     color="continent",
                     size="pop",
                     projection="natural earth",
                     text="country"
                     )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="f76ef406-f3c1-4a6f-9487-5bb92d4d255e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f76ef406-f3c1-4a6f-9487-5bb92d4d255e")) {                    Plotly.newPlot(                        "f76ef406-f3c1-4a6f-9487-5bb92d4d255e",                        [{"geo": "geo", "hovertemplate": "continent=Asia<br>pop=%{marker.size}<br>country=%{text}<br>iso_alpha=%{location}<extra></extra>", "legendgroup": "Asia", "locations": ["AFG", "BHR", "BGD", "KHM", "CHN", "HKG", "IND", "IDN", "IRN", "IRQ", "ISR", "JPN", "JOR", "KOR", "KOR", "KWT", "LBN", "MYS", "MNG", "MMR", "NPL", "OMN", "PAK", "PHL", "SAU", "SGP", "LKA", "SYR", "TWN", "THA", "VNM", "PSE", "YEM"], "marker": {"color": "#636efa", "size": [31889923, 708573, 150448339, 14131858, 1318683096, 6980412, 1110396331, 223547000, 69453570, 27499638, 6426679, 127467972, 6053193, 23301725, 49044790, 2505559, 3921278, 24821286, 2874127, 47761980, 28901790, 3204897, 169270617, 91077287, 27601038, 4553009, 20378239, 19314747, 23174294, 65068149, 85262356, 4018332, 22211743], "sizemode": "area", "sizeref": 3296707.74}, "name": "Asia", "showlegend": true, "text": ["Afghanistan", "Bahrain", "Bangladesh", "Cambodia", "China", "Hong Kong, China", "India", "Indonesia", "Iran", "Iraq", "Israel", "Japan", "Jordan", "Korea, Dem. Rep.", "Korea, Rep.", "Kuwait", "Lebanon", "Malaysia", "Mongolia", "Myanmar", "Nepal", "Oman", "Pakistan", "Philippines", "Saudi Arabia", "Singapore", "Sri Lanka", "Syria", "Taiwan", "Thailand", "Vietnam", "West Bank and Gaza", "Yemen, Rep."], "type": "scattergeo"}, {"geo": "geo", "hovertemplate": "continent=Europe<br>pop=%{marker.size}<br>country=%{text}<br>iso_alpha=%{location}<extra></extra>", "legendgroup": "Europe", "locations": ["ALB", "AUT", "BEL", "BIH", "BGR", "HRV", "CZE", "DNK", "FIN", "FRA", "DEU", "GRC", "HUN", "ISL", "IRL", "ITA", "MNE", "NLD", "NOR", "POL", "PRT", "ROU", "SRB", "SVK", "SVN", "ESP", "SWE", "CHE", "TUR", "GBR"], "marker": {"color": "#EF553B", "size": [3600523, 8199783, 10392226, 4552198, 7322858, 4493312, 10228744, 5468120, 5238460, 61083916, 82400996, 10706290, 9956108, 301931, 4109086, 58147733, 684736, 16570613, 4627926, 38518241, 10642836, 22276056, 10150265, 5447502, 2009245, 40448191, 9031088, 7554661, 71158647, 60776238], "sizemode": "area", "sizeref": 3296707.74}, "name": "Europe", "showlegend": true, "text": ["Albania", "Austria", "Belgium", "Bosnia and Herzegovina", "Bulgaria", "Croatia", "Czech Republic", "Denmark", "Finland", "France", "Germany", "Greece", "Hungary", "Iceland", "Ireland", "Italy", "Montenegro", "Netherlands", "Norway", "Poland", "Portugal", "Romania", "Serbia", "Slovak Republic", "Slovenia", "Spain", "Sweden", "Switzerland", "Turkey", "United Kingdom"], "type": "scattergeo"}, {"geo": "geo", "hovertemplate": "continent=Africa<br>pop=%{marker.size}<br>country=%{text}<br>iso_alpha=%{location}<extra></extra>", "legendgroup": "Africa", "locations": ["DZA", "AGO", "BEN", "BWA", "BFA", "BDI", "CMR", "CAF", "TCD", "COM", "COD", "COG", "CIV", "DJI", "EGY", "GNQ", "ERI", "ETH", "GAB", "GMB", "GHA", "GIN", "GNB", "KEN", "LSO", "LBR", "LBY", "MDG", "MWI", "MLI", "MRT", "MUS", "MAR", "MOZ", "NAM", "NER", "NGA", "REU", "RWA", "STP", "SEN", "SLE", "SOM", "ZAF", "SDN", "SWZ", "TZA", "TGO", "TUN", "UGA", "ZMB", "ZWE"], "marker": {"color": "#00cc96", "size": [33333216, 12420476, 8078314, 1639131, 14326203, 8390505, 17696293, 4369038, 10238807, 710960, 64606759, 3800610, 18013409, 496374, 80264543, 551201, 4906585, 76511887, 1454867, 1688359, 22873338, 9947814, 1472041, 35610177, 2012649, 3193942, 6036914, 19167654, 13327079, 12031795, 3270065, 1250882, 33757175, 19951656, 2055080, 12894865, 135031164, 798094, 8860588, 199579, 12267493, 6144562, 911877 ...

# %% [markdown]
# ### Filled "Choropleth" maps

# %%
fig = px.choropleth(df, locations='iso_alpha', color='lifeExp',
                           color_continuous_scale="Viridis",
                          )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="9fea0fca-c1f4-4d2c-a87f-c54ace8de5fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9fea0fca-c1f4-4d2c-a87f-c54ace8de5fc")) {                    Plotly.newPlot(                        "9fea0fca-c1f4-4d2c-a87f-c54ace8de5fc",                        [{"coloraxis": "coloraxis", "geo": "geo", "hovertemplate": "iso_alpha=%{location}<br>lifeExp=%{z}<extra></extra>", "locations": ["AFG", "ALB", "DZA", "AGO", "ARG", "AUS", "AUT", "BHR", "BGD", "BEL", "BEN", "BOL", "BIH", "BWA", "BRA", "BGR", "BFA", "BDI", "KHM", "CMR", "CAN", "CAF", "TCD", "CHL", "CHN", "COL", "COM", "COD", "COG", "CRI", "CIV", "HRV", "CUB", "CZE", "DNK", "DJI", "DOM", "ECU", "EGY", "SLV", "GNQ", "ERI", "ETH", "FIN", "FRA", "GAB", "GMB", "DEU", "GHA", "GRC", "GTM", "GIN", "GNB", "HTI", "HND", "HKG", "HUN", "ISL", "IND", "IDN", "IRN", "IRQ", "IRL", "ISR", "ITA", "JAM", "JPN", "JOR", "KEN", "KOR", "KOR", "KWT", "LBN", "LSO", "LBR", "LBY", "MDG", "MWI", "MYS", "MLI", "MRT", "MUS", "MEX", "MNG", "MNE", "MAR", "MOZ", "MMR", "NAM", "NPL", "NLD", "NZL", "NIC", "NER", "NGA", "NOR", "OMN", "PAK", "PAN", "PRY", "PER", "PHL", "POL", "PRT", "PRI", "REU", "ROU", "RWA", "STP", "SAU", "SEN", "SRB", "SLE", "SGP", "SVK", "SVN", "SOM", "ZAF", "ESP", "LKA", "SDN", "SWZ", "SWE", "CHE", "SYR", "TWN", "TZA", "THA", "TGO", "TTO", "TUN", "TUR", "UGA", "GBR", "USA", "URY", "VEN", "VNM", "PSE", "YEM", "ZMB", "ZWE"], "name": "", "type": "choropleth", "z": [43.828, 76.423, 72.301, 42.731, 75.32, 81.235, 79.829, 75.635, 64.062, 79.441, 56.728, 65.554, 74.852, 50.728, 72.39, 73.005, 52.295, 49.58, 59.723, 50.43, 80.653, 44.74100000000001, 50.651, 78.553, 72.961, 72.889, 65.152, 46.461999999999996, 55.321999999999996, 78.782, 48.328, 75.748, 78.273, 76.486, 78.332, 54.791000000000004, 72.235, 74.994, 71.33800000000001, 71.878, 51.57899999999999, 58.04, 52.946999999999996, 79.313, 80.657, 56.735, 59.448, 79.406, 60.022, 79.483, 70.259, 56.007, 46.388000000000005, 60.916000000000004, 70.19800000000001, 82.208, 73.33800000000001, 81.757, 64.69800000000001, 70.65, 70.964, 59.545, 78.885, 80.745, 80.546, 72.567, 82.603, 72.535, 54.11, 67.297, 78.623, 77.58800000000001, 71.993, 42.592, 45.678000000000004, 73.952, 59.443000000000005, 48.303000000000004, 74.241, 54.467, 64.164, 72.801, 76.195, 66.803, 74.543, 71.164, 42.082, 62.068999999999996, 52.906000000000006, 63.785, 79.762, 80.204, 72.899, 56.867, 46.858999999999995, 80.196, 75.64, 65.483, 75.53699999999999, 71.752, 71.421, 71.688, 75.563, 78.098, 78.74600000000001, 76.442, 72.476, 46.242, 65.528, 72.777, 63.062, 74.002, 42.568000000000005, 79.972, 74.663, 77.926, 48.159, 49.339, 80.941, 72.396, 58.556000000000004, 39.613, 80.884, 81.70100000000001, 74.143, 78.4, 52.516999999999996, 70.616, 58.42, 69.819, 73.923, 71.777, 51.542, 79.425, 78.242, 76.384, 73.747, 74.249, 73.422, 62.698, 42.38399999999999, 43.486999999999995]}],                        {"coloraxis": {"colorbar": {"title": {"text": "lifeExp"}}, "colorscale": [[0.0, "#440154"], [0.1111111111111111, "#482878"], [0.2222222222222222, "#3e4989"], [0.3333333333333333, "#31688e"], [0.4444444444444444, "#26828e"], [0.5555555555555556, "#1f9e89"], [0.6666666666666666, "#35b779"], [0.7777777777777778, "#6ece58"], [0.8888888888888888, "#b5de2b"], [1.0, "#fde725"]]}, "geo": {"center": {}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}}, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "wh ...

# %% [markdown]
# ### Scatter Plots with `Mapbox` & `GeoPandas`

# %% [markdown]
# 1st: `pip install geopandas` <br>
# Optional: Sign up for a mapbox account at https://account.mapbox.com/

# %%
import geopandas as gpd
import pandas as pd

# %%
peaks = pd.read_csv('co_14ers.csv')
peaks = gpd.GeoDataFrame(peaks, 
                         geometry=gpd.points_from_xy(peaks.lon,peaks.lat))
peaks.head()
# Out:
#                Peak               Range  ...       lon                     geometry
# 0       Windom Peak    Needle Mountains  ... -107.5919  POINT (-107.59190 37.62120)
# 1       Wilson Peak  San Juan Mountains  ... -107.9847  POINT (-107.98470 37.86030)
# 2   Wetterhorn Peak  San Juan Mountains  ... -107.5109  POINT (-107.51090 38.06070)
# 3  Uncompahgre Peak  San Juan Mountains  ... -107.4621  POINT (-107.46210 38.07170)
# 4      Torreys Peak         Front Range  ... -105.8212  POINT (-105.82120 39.64280)
#
# [5 rows x 8 columns]

# %%
peaks['size'] = 15

fig = px.scatter_mapbox(peaks,
                        lat=peaks.geometry.y,
                        lon=peaks.geometry.x,
                        color="Range",
                        hover_name="Peak",
                        text="Peak",
                        size="size",
                        zoom=5)

# %%
fig.update_layout(
    title = '14ers of Colorado',
    mapbox_style="white-bg",
    mapbox_layers=[
        {
            "below": 'traces',
            "sourcetype": "raster",
            "sourceattribution": "United States Geological Survey",
            "source": [
                "https://basemap.nationalmap.gov/arcgis/rest/services/USGSImageryOnly/MapServer/tile/{z}/{y}/{x}"
            ]
        }
      ])

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="6be33d44-9d75-463f-9c11-90c1d370ebc9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6be33d44-9d75-463f-9c11-90c1d370ebc9")) {                    Plotly.newPlot(                        "6be33d44-9d75-463f-9c11-90c1d370ebc9",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>Range=Needle Mountains<br>size=%{marker.size}<br>Peak=%{text}<br>lat=%{lat}<br>lon=%{lon}<extra></extra>", "hovertext": ["Windom Peak"], "lat": [37.6212], "legendgroup": "Needle Mountains", "lon": [-107.5919], "marker": {"color": "#636efa", "size": [15], "sizemode": "area", "sizeref": 0.0375}, "mode": "markers+text", "name": "Needle Mountains", "showlegend": true, "subplot": "mapbox", "text": ["Windom Peak"], "type": "scattermapbox"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Range=San Juan Mountains<br>size=%{marker.size}<br>Peak=%{text}<br>lat=%{lat}<br>lon=%{lon}<extra></extra>", "hovertext": ["Wilson Peak", "Wetterhorn Peak", "Uncompahgre Peak", "Sunshine Peak", "Sunlight Peak", "Redcloud Peak", "Mount Eolus", "Handies Peak"], "lat": [37.8603, 38.0607, 38.0717, 37.9228, 37.6274, 37.941, 37.6218, 37.913000000000004], "legendgroup": "San Juan Mountains", "lon": [-107.9847, -107.5109, -107.4621, -107.4256, -107.5959, -107.4219, -107.6227, -107.5044], "marker": {"color": "#EF553B", "size": [15, 15, 15, 15, 15, 15, 15, 15], "sizemode": "area", "sizeref": 0.0375}, "mode": "markers+text", "name": "San Juan Mountains", "showlegend": true, "subplot": "mapbox", "text": ["Wilson Peak", "Wetterhorn Peak", "Uncompahgre Peak", "Sunshine Peak", "Sunlight Peak", "Redcloud Peak", "Mount Eolus", "Handies Peak"], "type": "scattermapbox"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Range=Front Range<br>size=%{marker.size}<br>Peak=%{text}<br>lat=%{lat}<br>lon=%{lon}<extra></extra>", "hovertext": ["Torreys Peak", "Pikes Peak", "Mount Evans", "Mount Bierstadt", "Longs Peak", "Grays Peak"], "lat": [39.6428, 38.8405, 39.5883, 39.5826, 40.255, 39.6339], "legendgroup": "Front Range", "lon": [-105.8212, -105.0442, -105.6438, -105.6688, -105.6151, -105.8176], "marker": {"color": "#00cc96", "size": [15, 15, 15, 15, 15, 15], "sizemode": "area", "sizeref": 0.0375}, "mode": "markers+text", "name": "Front Range", "showlegend": true, "subplot": "mapbox", "text": ["Torreys Peak", "Pikes Peak", "Mount Evans", "Mount Bierstadt", "Longs Peak", "Grays Peak"], "type": "scattermapbox"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Range=Sawatch Range<br>size=%{marker.size}<br>Peak=%{text}<br>lat=%{lat}<br>lon=%{lon}<extra></extra>", "hovertext": ["Tabeguache Peak", "Mount Yale", "Mount Shavano", "Mount Princeton", "Mount of the Holy Cross", "Mount Massive", "Mount Harvard", "Mount Elbert", "Mount Columbia", "Mount Belford", "Mount Antero", "Missouri Mountain", "La Plata Peak", "Huron Peak"], "lat": [38.6255, 38.8442, 38.6192, 38.7492, 39.4668, 39.1875, 38.9244, 39.1178, 38.9039, 38.9607, 38.6741, 38.9476, 39.0294, 38.9455], "legendgroup": "Sawatch Range", "lon": [-106.2509, -106.3138, -106.2393, -106.2424, -106.4817, -106.4757, -106.3207, -106.4454, -106.2975, -106.3607, -106.2462, -106.3785, -106.4729, -106.4381], "marker": {"color": "#ab63fa", "size": [15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15], "sizemode": "area", "sizeref": 0.0375}, "mode": "markers+text", "name": "Sawatch Range", "showlegend": true, "subplot": "mapbox", "text": ["Tabeguache Peak", "Mount Yale", "Mount Shavano", "Mount Princeton", "Mount of the Holy Cross", "Mount Massive", "Mount Harvard", "Mount Elbert", "Mount Columbia", "Mount Belford", "Mount Antero", "Missouri Mountain", "La Plata Peak", "Huron Peak"], "type": "scattermapbox"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Range=Elk M ...
